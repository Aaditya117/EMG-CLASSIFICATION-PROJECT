# %%
#Logistic Regression Classifier

# %%
# Importing the libraries

# %%
# Importing the libraries
import numpy as np
import pandas as pd
import seaborn as sn
import matplotlib.pyplot as plt

# %%
#Importing the dataset

# %%
# Importing the train_set
train_dataset = pd.read_csv('S11_trainset_P135_70.csv')
X_train = train_dataset.iloc[:, :-1].values
y_train = train_dataset.iloc[:, -1].values

# %%
# Importing the test_set
test_dataset = pd.read_csv('S11_testset_P12345_30.csv')
X_test = test_dataset.iloc[:, :-1].values
y_test = test_dataset.iloc[:, -1].values

# %%
#Feature Scaling

# %%
# Feature Scaling
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %%
#Dataset Analysis

# %%
#Training Set

# %%
print(X_train)
# Out:
# [[-1.43326266 -1.26507519 -0.90008675 ...  0.44118127 -1.8010007
#   -1.43829061]
#  [-1.44040247 -1.21630081 -0.98510071 ...  0.40343083 -2.221277
#   -0.28863125]
#  [-1.43489779 -1.15128777 -1.02908836 ...  0.37463345 -1.49660612
#   -0.30440131]
#  ...
#  [ 2.07198819  1.94838413  1.68090364 ... -0.59124154 -1.02788849
#   -1.78618436]
#  [ 2.09979519  1.74381059  2.01441561 ... -1.0473856  -0.88856439
#   -1.79717507]
#  [ 2.10695401  1.86846556  1.54508316 ... -1.89897944 -1.04798522
#   -1.73708396]]

# %%
np.shape(X_train)
# Out:
# (19775, 42)

# %%
print(y_train)
# Out:
# [1 1 1 ... 8 8 8]

# %%
np.shape(y_train)
# Out:
# (19775,)

# %%
#Test Set

# %%
print(X_test)
# Out:
# [[-0.99941796 -1.16961593 -0.88441106 ...  0.36434032 -1.3818566
#   -0.11557687]
#  [-1.41262652 -1.19983127 -0.9681693  ...  0.41747506 -1.55107197
#   -1.11668721]
#  [-1.48971104 -1.26202142 -1.04290291 ...  0.44069898 -1.65550309
#   -1.25764562]
#  ...
#  [ 2.45412583  1.80876812  1.68319052 ... -1.18075782 -1.18838277
#   -1.17617009]
#  [ 2.03922737  1.73344288  2.02560976 ... -1.54430454 -2.11379986
#   -1.62503721]
#  [ 2.08489942  1.94368976  1.91574592 ... -0.64980101 -1.24095979
#   -1.73119061]]

# %%
np.shape(X_test)
# Out:
# (7039, 42)

# %%
print(y_test)
# Out:
# [1 1 1 ... 8 8 8]

# %%
np.shape(y_test)
# Out:
# (7039,)

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import classification_report
from sklearn.linear_model import LogisticRegression

# Set the parameters by cross-validation
tuned_parameters = [{ "solver" : ['newton-cg','lbfgs', 'liblinear', 'sag','saga'],
                       "C" : [0.001, 0.01, 0.1, 1, 10, 100, 1000],
                       "max_iter":[250,500,1000,1500,2000],
                       "penalty":['l1', 'l2', 'elasticnet']}]
             

print("# Tuning hyper-parameters for Logistic Regression Classifier")
print()

clf = GridSearchCV(LogisticRegression(random_state = 0), tuned_parameters, scoring='accuracy', cv = 5)

clf.fit(X_train, y_train)

print("Best parameters set found on training set:")
print()
print(clf.best_params_)
print()
print("Grid scores on training set:")
print()
means = clf.cv_results_['mean_test_score']
stds = clf.cv_results_['std_test_score']
for mean, std, params in zip(means, stds, clf.cv_results_['params']):
    print("%0.3f (+/-%0.03f) for %r"
            % (mean, std * 2, params))
print()
# Out:
# # Tuning hyper-parameters for Logistic Regression Classifier
# C:\Users\user\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: Solver newton-cg supports only 'l2' or 'none' penalties, got l1 penalty.
#
#   FitFailedWarning)
# C:\Users\user\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: Solver lbfgs supports only 'l2' or 'none' penalties, got l1 penalty.
#
#   FitFailedWarning)
# C:\Users\user\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: Solver sag supports only 'l2' or 'none' penalties, got l1 penalty.
#
#   FitFailedWarning)
# C:\Users\user\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: Solver newton-cg supports only 'l2' or 'none' penalties, got elasticnet penalty.
#
#   FitFailedWarning)
# C:\Users\user\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: Solver lbfgs supports only 'l2' or 'none' penalties, got elasticnet penalty.
#
#   FitFailedWarning)
# C:\Users\user\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: Only 'saga' solver supports elasticnet penalty, got solver=liblinear.
#
#   FitFailedWarning)
# C:\Users\user\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: Solver sag supports only 'l2' or 'none' penalties, got elasticnet penalty.
#
#   FitFailedWarning)
# C:\Users\user\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: l1_ratio must be between 0 and 1; got (l1_ratio=None)
#
#   FitFailedWarning)
# C:\Users\user\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: Solver newton-cg supports only 'l2' or 'none' penalties, got l1 penalty.
#
#   FitFailedWarning)
# C:\Users\user\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: Solver lbfgs supports only 'l2' or 'none' penalties, got l1 penalty.
#
#   FitFailedWarning)
# C:\Users\user\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: Solver sag supports only 'l2' or 'none' penalties, got l1 penalty.
#
#   FitFailedWarning)
# C:\Users\user\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: Solver newton-cg supports only 'l2' or 'none' penalties, got elasticnet penalty.
#
#   FitFailedWarning)
# C:\Users\user\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: Solver lbfgs supports only 'l2' or 'none' penalties, got elasticnet penalty.
#
#   FitFailedWarning)
# C:\Users\user\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: Only 'saga' solver supports elasticnet penalty, got solver=liblinear.
#
#   FitFailedWarning)
# C:\Users\user\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: Solver sag supports only 'l2' or 'none' penalties, got elasticnet penalty.
#
#   FitFailedWarning)
# C:\Users\user\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: l1_ratio must be between 0 and 1; got (l1_ratio=None)
#
#   FitFailedWarning)
# C:\Users\user\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: Solver newton-cg supports only 'l2' or 'none' penalties, got l1 penalty.
#
#   FitFailedWarning)
# C:\Users\user\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: Solver lbfgs supports only 'l2' or 'none' penalties, got l1 penalty.
#
#   FitFailedWarning)
# C:\Users\user\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: Solver sag supports only 'l2' or 'none' penalties, got l1 penalty.
#
#   FitFailedWarning)
# C:\Users\user\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: Solver newton-cg supports only 'l2' or 'none' penalties, got elasticnet penalty.
#
#   FitFailedWarning)
# C:\Users\user\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: Solver lbfgs supports only 'l2' or 'none' penalties, got elasticnet penalty.
#
#   FitFailedWarning)
# C:\Users\user\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: Only 'saga' solver supports elasticnet penalty, got solver=liblinear.
#
#   FitFailedWarning)
# C:\Users\user\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: Solver sag supports only 'l2' or 'none' penalties, got elasticnet penalty.
#
#   FitFailedWarning)
# C:\Users\user\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: l1_ratio must be between 0 and 1; got (l1_ratio=None)
#
#   FitFailedWarning)
# C:\Users\user\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: Solver newton-cg supports only 'l2' or 'none' penalties, got l1 penalty.
#
#   FitFailedWarning)
# C:\Users\user\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: Solver lbfgs supports only 'l2' or 'none' penalties, got l1 penalty.
#
#   FitFailedWarning)
# C:\Users\user\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: Solver sag supports only 'l2' or 'none' penalties, got l1 penalty.
#
#   FitFailedWarning)
# C:\Users\user\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: Solver newton-cg supports only 'l2' or 'none' penalties, got elasticnet penalty.
#
#   FitFailedWarning)
# C:\Users\user\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: Solver lbfgs supports only 'l2' or 'none' penalties, got elasticnet penalty.
#
#   FitFailedWarning)
# C:\Users\user\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: Only 'saga' solver supports elasticnet penalty, got solver=liblinear.
#
#   FitFailedWarning)
# C:\Users\user\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: Solver sag supports only 'l2' or 'none' penalties, got elasticnet penalty.
#
#   FitFailedWarning)
# C:\Users\user\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: l1_ratio must be between 0 and 1; got (l1_ratio=None)
#
#   FitFailedWarning)
# C:\Users\user\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: Solver newton-cg supports only 'l2' or 'none' penalties, got l1 penalty.
#
#   FitFailedWarning)
# C:\Users\user\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: Solver lbfgs supports only 'l2' or 'none' penalties, got l1 penalty.
#
#   FitFailedWarning)
# C:\Users\user\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: Solver sag supports only 'l2' or 'none' penalties, got l1 penalty.
#
#   FitFailedWarning)
# C:\Users\user\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: Solver newton-cg supports only 'l2' or 'none' penalties, got elasticnet penalty.
#
#   FitFailedWarning)
# C:\Users\user\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: Solver lbfgs supports only 'l2' or 'none' penalties, got elasticnet penalty.
#
#   FitFailedWarning)
# C:\Users\user\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: Only 'saga' solver supports elasticnet penalty, got solver=liblinear.
#
#   FitFailedWarning)
# C:\Users\user\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: Solver sag supports only 'l2' or 'none' penalties, got elasticnet penalty.
#
#   FitFailedWarning)
# C:\Users\user\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: l1_ratio must be between 0 and 1; got (l1_ratio=None)
#
#   FitFailedWarning)
# C:\Users\user\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: Solver newton-cg supports only 'l2' or 'none' penalties, got l1 penalty.
#
#   FitFailedWarning)
# C:\Users\user\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: Solver lbfgs supports only 'l2' or 'none' penalties, got l1 penalty.
#
#   FitFailedWarning)
# C:\Users\user\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: Solver sag supports only 'l2' or 'none' penalties, got l1 penalty.
#
#   FitFailedWarning)
# C:\Users\user\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: Solver newton-cg supports only 'l2' or 'none' penalties, got elasticnet penalty.
#
#   FitFailedWarning)
# C:\Users\user\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: Solver lbfgs supports only 'l2' or 'none' penalties, got elasticnet penalty.
#
#   FitFailedWarning)
# C:\Users\user\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: Only 'saga' solver supports elasticnet penalty, got solver=liblinear.
#
#   FitFailedWarning)
# C:\Users\user\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: Solver sag supports only 'l2' or 'none' penalties, got elasticnet penalty.
#
#   FitFailedWarning)
# C:\Users\user\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: l1_ratio must be between 0 and 1; got (l1_ratio=None)
#
#   FitFailedWarning)
# C:\Users\user\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: Solver newton-cg supports only 'l2' or 'none' penalties, got l1 penalty.
#
#   FitFailedWarning)
# C:\Users\user\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: Solver lbfgs supports only 'l2' or 'none' penalties, got l1 penalty.
#
#   FitFailedWarning)
# C:\Users\user\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: Solver sag supports only 'l2' or 'none' penalties, got l1 penalty.
#
#   FitFailedWarning)
# C:\Users\user\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: Solver newton-cg supports only 'l2' or 'none' penalties, got elasticnet penalty.
#
#   FitFailedWarning)
# C:\Users\user\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: Solver lbfgs supports only 'l2' or 'none' penalties, got elasticnet penalty.
#
#   FitFailedWarning)
# C:\Users\user\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: Only 'saga' solver supports elasticnet penalty, got solver=liblinear.
#
#   FitFailedWarning)
# C:\Users\user\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: Solver sag supports only 'l2' or 'none' penalties, got elasticnet penalty.
#
#   FitFailedWarning)
# C:\Users\user\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: l1_ratio must be between 0 and 1; got (l1_ratio=None)
#
#   FitFailedWarning)
# C:\Users\user\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: Solver newton-cg supports only 'l2' or 'none' penalties, got l1 penalty.
#
#   FitFailedWarning)
# C:\Users\user\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: Solver lbfgs supports only 'l2' or 'none' penalties, got l1 penalty.
#
#   FitFailedWarning)
# C:\Users\user\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: Solver sag supports only 'l2' or 'none' penalties, got l1 penalty.
#
#   FitFailedWarning)
# C:\Users\user\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: Solver newton-cg supports only 'l2' or 'none' penalties, got elasticnet penalty.
#
#   FitFailedWarning)
# C:\Users\user\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: Solver lbfgs supports only 'l2' or 'none' penalties, got elasticnet penalty.
#
#   FitFailedWarning)
# C:\Users\user\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: Only 'saga' solver supports elasticnet penalty, got solver=liblinear.
#
#   FitFailedWarning)
# C:\Users\user\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: Solver sag supports only 'l2' or 'none' penalties, got elasticnet penalty.
#
#   FitFailedWarning)
# C:\Users\user\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: l1_ratio must be between 0 and 1; got (l1_ratio=None)
#
#   FitFailedWarning)
# C:\Users\user\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: Solver newton-cg supports only 'l2' or 'none' penalties, got l1 penalty.
#
#   FitFailedWarning)
# C:\Users\user\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: Solver lbfgs supports only 'l2' or 'none' penalties, got l1 penalty.
#
#   FitFailedWarning)
# C:\Users\user\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: Solver sag supports only 'l2' or 'none' penalties, got l1 penalty.
#
#   FitFailedWarning)
# C:\Users\user\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: Solver newton-cg supports only 'l2' or 'none' penalties, got elasticnet penalty.
#
#   FitFailedWarning)
# C:\Users\user\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: Solver lbfgs supports only 'l2' or 'none' penalties, got elasticnet penalty.
#
#   FitFailedWarning)
# C:\Users\user\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: Only 'saga' solver supports elasticnet penalty, got solver=liblinear.
#
#   FitFailedWarning)
# C:\Users\user\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: Solver sag supports only 'l2' or 'none' penalties, got elasticnet penalty.
#
#   FitFailedWarning)
# C:\Users\user\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: l1_ratio must be between 0 and 1; got (l1_ratio=None)
#
#   FitFailedWarning)
# C:\Users\user\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: Solver newton-cg supports only 'l2' or 'none' penalties, got l1 penalty.
#
#   FitFailedWarning)
# C:\Users\user\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: Solver lbfgs supports only 'l2' or 'none' penalties, got l1 penalty.
#
#   FitFailedWarning)
# C:\Users\user\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: Solver sag supports only 'l2' or 'none' penalties, got l1 penalty.
#
#   FitFailedWarning)
# C:\Users\user\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: Solver newton-cg supports only 'l2' or 'none' penalties, got elasticnet penalty.
#
#   FitFailedWarning)
# C:\Users\user\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: Solver lbfgs supports only 'l2' or 'none' penalties, got elasticnet penalty.
#
#   FitFailedWarning)
# C:\Users\user\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: Only 'saga' solver supports elasticnet penalty, got solver=liblinear.
#
#   FitFailedWarning)
# C:\Users\user\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: Solver sag supports only 'l2' or 'none' penalties, got elasticnet penalty.
#
#   FitFailedWarning)
# C:\Users\user\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: l1_ratio must be between 0 and 1; got (l1_ratio=None)
#
#   FitFailedWarning)
# C:\Users\user\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: Solver newton-cg supports only 'l2' or 'none' penalties, got l1 penalty.
#
#   FitFailedWarning)
# C:\Users\user\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: Solver lbfgs supports only 'l2' or 'none' penalties, got l1 penalty.
#
#   FitFailedWarning)
# C:\Users\user\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: Solver sag supports only 'l2' or 'none' penalties, got l1 penalty.
#
#   FitFailedWarning)
# C:\Users\user\anaconda3\lib\site-packages\sklearn\linear_model\_sag.py:330: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   "the coef_ did not converge", ConvergenceWarning)
# C:\Users\user\anaconda3\lib\site-packages\sklearn\linear_model\_sag.py:330: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   "the coef_ did not converge", ConvergenceWarning)
# C:\Users\user\anaconda3\lib\site-packages\sklearn\linear_model\_sag.py:330: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   "the coef_ did not converge", ConvergenceWarning)
# C:\Users\user\anaconda3\lib\site-packages\sklearn\linear_model\_sag.py:330: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   "the coef_ did not converge", ConvergenceWarning)
# C:\Users\user\anaconda3\lib\site-packages\sklearn\linear_model\_sag.py:330: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   "the coef_ did not converge", ConvergenceWarning)
# C:\Users\user\anaconda3\lib\site-packages\sklearn\linear_model\_sag.py:330: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   "the coef_ did not converge", ConvergenceWarning)
# C:\Users\user\anaconda3\lib\site-packages\sklearn\linear_model\_sag.py:330: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   "the coef_ did not converge", ConvergenceWarning)
# C:\Users\user\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: Solver newton-cg supports only 'l2' or 'none' penalties, got elasticnet penalty.
#
#   FitFailedWarning)
# C:\Users\user\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: Solver lbfgs supports only 'l2' or 'none' penalties, got elasticnet penalty.
#
#   FitFailedWarning)
# C:\Users\user\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: Only 'saga' solver supports elasticnet penalty, got solver=liblinear.
#
#   FitFailedWarning)
# C:\Users\user\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: Solver sag supports only 'l2' or 'none' penalties, got elasticnet penalty.
#
#   FitFailedWarning)
# C:\Users\user\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: l1_ratio must be between 0 and 1; got (l1_ratio=None)
#
#   FitFailedWarning)
# C:\Users\user\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: Solver newton-cg supports only 'l2' or 'none' penalties, got l1 penalty.
#
#   FitFailedWarning)
# C:\Users\user\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: Solver lbfgs supports only 'l2' or 'none' penalties, got l1 penalty.
#
#   FitFailedWarning)
# C:\Users\user\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: Solver sag supports only 'l2' or 'none' penalties, got l1 penalty.
#
#   FitFailedWarning)
# C:\Users\user\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: Solver newton-cg supports only 'l2' or 'none' penalties, got elasticnet penalty.
#
#   FitFailedWarning)
# C:\Users\user\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: Solver lbfgs supports only 'l2' or 'none' penalties, got elasticnet penalty.
#
#   FitFailedWarning)
# C:\Users\user\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: Only 'saga' solver supports elasticnet penalty, got solver=liblinear.
#
#   FitFailedWarning)
# C:\Users\user\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: Solver sag supports only 'l2' or 'none' penalties, got elasticnet penalty.
#
#   FitFailedWarning)
# C:\Users\user\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: l1_ratio must be between 0 and 1; got (l1_ratio=None)
#
#   FitFailedWarning)
# C:\Users\user\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: Solver newton-cg supports only 'l2' or 'none' penalties, got l1 penalty.
#
#   FitFailedWarning)
# C:\Users\user\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: Solver lbfgs supports only 'l2' or 'none' penalties, got l1 penalty.
#
#   FitFailedWarning)
# C:\Users\user\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: Solver sag supports only 'l2' or 'none' penalties, got l1 penalty.
#
#   FitFailedWarning)
# C:\Users\user\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: Solver newton-cg supports only 'l2' or 'none' penalties, got elasticnet penalty.
#
#   FitFailedWarning)
# C:\Users\user\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: Solver lbfgs supports only 'l2' or 'none' penalties, got elasticnet penalty.
#
#   FitFailedWarning)
# C:\Users\user\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: Only 'saga' solver supports elasticnet penalty, got solver=liblinear.
#
#   FitFailedWarning)
# C:\Users\user\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: Solver sag supports only 'l2' or 'none' penalties, got elasticnet penalty.
#
#   FitFailedWarning)
# C:\Users\user\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: l1_ratio must be between 0 and 1; got (l1_ratio=None)
#
#   FitFailedWarning)
# C:\Users\user\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: Solver newton-cg supports only 'l2' or 'none' penalties, got l1 penalty.
#
#   FitFailedWarning)
# C:\Users\user\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: Solver lbfgs supports only 'l2' or 'none' penalties, got l1 penalty.
#
#   FitFailedWarning)
# C:\Users\user\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: Solver sag supports only 'l2' or 'none' penalties, got l1 penalty.
#
#   FitFailedWarning)
# C:\Users\user\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: Solver newton-cg supports only 'l2' or 'none' penalties, got elasticnet penalty.
#
#   FitFailedWarning)
# C:\Users\user\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: Solver lbfgs supports only 'l2' or 'none' penalties, got elasticnet penalty.
#
#   FitFailedWarning)
# C:\Users\user\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: Only 'saga' solver supports elasticnet penalty, got solver=liblinear.
#
#   FitFailedWarning)
# C:\Users\user\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: Solver sag supports only 'l2' or 'none' penalties, got elasticnet penalty.
#
#   FitFailedWarning)
# C:\Users\user\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: l1_ratio must be between 0 and 1; got (l1_ratio=None)
#
#   FitFailedWarning)
# C:\Users\user\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: Solver newton-cg supports only 'l2' or 'none' penalties, got l1 penalty.
#
#   FitFailedWarning)
# C:\Users\user\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: Solver lbfgs supports only 'l2' or 'none' penalties, got l1 penalty.
#
#   FitFailedWarning)
# C:\Users\user\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: Solver sag supports only 'l2' or 'none' penalties, got l1 penalty.
#
#   FitFailedWarning)
# C:\Users\user\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: Solver newton-cg supports only 'l2' or 'none' penalties, got elasticnet penalty.
#
#   FitFailedWarning)
# C:\Users\user\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: Solver lbfgs supports only 'l2' or 'none' penalties, got elasticnet penalty.
#
#   FitFailedWarning)
# C:\Users\user\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: Only 'saga' solver supports elasticnet penalty, got solver=liblinear.
#
#   FitFailedWarning)
# C:\Users\user\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: Solver sag supports only 'l2' or 'none' penalties, got elasticnet penalty.
#
#   FitFailedWarning)
# C:\Users\user\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: l1_ratio must be between 0 and 1; got (l1_ratio=None)
#
#   FitFailedWarning)
# C:\Users\user\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: Solver newton-cg supports only 'l2' or 'none' penalties, got l1 penalty.
#
#   FitFailedWarning)
# C:\Users\user\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: Solver lbfgs supports only 'l2' or 'none' penalties, got l1 penalty.
#
#   FitFailedWarning)
# C:\Users\user\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: Solver sag supports only 'l2' or 'none' penalties, got l1 penalty.
#
#   FitFailedWarning)
# C:\Users\user\anaconda3\lib\site-packages\sklearn\linear_model\_sag.py:330: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   "the coef_ did not converge", ConvergenceWarning)
# C:\Users\user\anaconda3\lib\site-packages\sklearn\linear_model\_sag.py:330: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   "the coef_ did not converge", ConvergenceWarning)
# C:\Users\user\anaconda3\lib\site-packages\sklearn\linear_model\_sag.py:330: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   "the coef_ did not converge", ConvergenceWarning)
# C:\Users\user\anaconda3\lib\site-packages\sklearn\linear_model\_sag.py:330: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   "the coef_ did not converge", ConvergenceWarning)
# C:\Users\user\anaconda3\lib\site-packages\sklearn\linear_model\_sag.py:330: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   "the coef_ did not converge", ConvergenceWarning)
# C:\Users\user\anaconda3\lib\site-packages\sklearn\linear_model\_sag.py:330: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   "the coef_ did not converge", ConvergenceWarning)
# C:\Users\user\anaconda3\lib\site-packages\sklearn\linear_model\_sag.py:330: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   "the coef_ did not converge", ConvergenceWarning)
# C:\Users\user\anaconda3\lib\site-packages\sklearn\linear_model\_sag.py:330: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   "the coef_ did not converge", ConvergenceWarning)
# C:\Users\user\anaconda3\lib\site-packages\sklearn\linear_model\_sag.py:330: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   "the coef_ did not converge", ConvergenceWarning)
# C:\Users\user\anaconda3\lib\site-packages\sklearn\linear_model\_sag.py:330: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   "the coef_ did not converge", ConvergenceWarning)
# C:\Users\user\anaconda3\lib\site-packages\sklearn\linear_model\_sag.py:330: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   "the coef_ did not converge", ConvergenceWarning)
# C:\Users\user\anaconda3\lib\site-packages\sklearn\linear_model\_sag.py:330: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   "the coef_ did not converge", ConvergenceWarning)
# C:\Users\user\anaconda3\lib\site-packages\sklearn\linear_model\_sag.py:330: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   "the coef_ did not converge", ConvergenceWarning)
# C:\Users\user\anaconda3\lib\site-packages\sklearn\linear_model\_sag.py:330: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   "the coef_ did not converge", ConvergenceWarning)
# C:\Users\user\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: Solver newton-cg supports only 'l2' or 'none' penalties, got elasticnet penalty.
#
#   FitFailedWarning)
# C:\Users\user\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: Solver lbfgs supports only 'l2' or 'none' penalties, got elasticnet penalty.
#
#   FitFailedWarning)
# C:\Users\user\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: Only 'saga' solver supports elasticnet penalty, got solver=liblinear.
#
#   FitFailedWarning)
# C:\Users\user\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: Solver sag supports only 'l2' or 'none' penalties, got elasticnet penalty.
#
#   FitFailedWarning)
# C:\Users\user\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: l1_ratio must be between 0 and 1; got (l1_ratio=None)
#
#   FitFailedWarning)
# C:\Users\user\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: Solver newton-cg supports only 'l2' or 'none' penalties, got l1 penalty.
#
#   FitFailedWarning)
# C:\Users\user\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: Solver lbfgs supports only 'l2' or 'none' penalties, got l1 penalty.
#
#   FitFailedWarning)
# C:\Users\user\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: Solver sag supports only 'l2' or 'none' penalties, got l1 penalty.
#
#   FitFailedWarning)
# C:\Users\user\anaconda3\lib\site-packages\sklearn\linear_model\_sag.py:330: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   "the coef_ did not converge", ConvergenceWarning)
# C:\Users\user\anaconda3\lib\site-packages\sklearn\linear_model\_sag.py:330: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   "the coef_ did not converge", ConvergenceWarning)
# C:\Users\user\anaconda3\lib\site-packages\sklearn\linear_model\_sag.py:330: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   "the coef_ did not converge", ConvergenceWarning)
# C:\Users\user\anaconda3\lib\site-packages\sklearn\linear_model\_sag.py:330: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   "the coef_ did not converge", ConvergenceWarning)
# C:\Users\user\anaconda3\lib\site-packages\sklearn\linear_model\_sag.py:330: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   "the coef_ did not converge", ConvergenceWarning)
# C:\Users\user\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# ValueError: Solver newton-cg supports only 'l2' or 'none' penalties, got elasticnet penalty.
#
#   FitFailedWarning)
# ...
# nan (+/-nan) for {'C': 10, 'max_iter': 1000, 'penalty': 'elasticnet', 'solver': 'sag'}
# nan (+/-nan) for {'C': 10, 'max_iter': 1000, 'penalty': 'elasticnet', 'solver': 'saga'}
# nan (+/-nan) for {'C': 10, 'max_iter': 1500, 'penalty': 'l1', 'solver': 'newton-cg'}
# nan (+/-nan) for {'C': 10, 'max_iter': 1500, 'penalty': 'l1', 'solver': 'lbfgs'}
# 0.988 (+/-0.016) for {'C': 10, 'max_iter': 1500, 'penalty': 'l1', 'solver': 'liblinear'}
# nan (+/-nan) for {'C': 10, 'max_iter': 1500, 'penalty': 'l1', 'solver': 'sag'}
# 0.986 (+/-0.032) for {'C': 10, 'max_iter': 1500, 'penalty': 'l1', 'solver': 'saga'}
# 0.988 (+/-0.026) for {'C': 10, 'max_iter': 1500, 'penalty': 'l2', 'solver': 'newton-cg'}
# 0.988 (+/-0.026) for {'C': 10, 'max_iter': 1500, 'penalty': 'l2', 'solver': 'lbfgs'}
# 0.987 (+/-0.015) for {'C': 10, 'max_iter': 1500, 'penalty': 'l2', 'solver': 'liblinear'}
# 0.988 (+/-0.026) for {'C': 10, 'max_iter': 1500, 'penalty': 'l2', 'solver': 'sag'}
# 0.988 (+/-0.026) for {'C': 10, 'max_iter': 1500, 'penalty': 'l2', 'solver': 'saga'}
# nan (+/-nan) for {'C': 10, 'max_iter': 1500, 'penalty': 'elasticnet', 'solver': 'newton-cg'}
# nan (+/-nan) for {'C': 10, 'max_iter': 1500, 'penalty': 'elasticnet', 'solver': 'lbfgs'}
# nan (+/-nan) for {'C': 10, 'max_iter': 1500, 'penalty': 'elasticnet', 'solver': 'liblinear'}
# nan (+/-nan) for {'C': 10, 'max_iter': 1500, 'penalty': 'elasticnet', 'solver': 'sag'}
# nan (+/-nan) for {'C': 10, 'max_iter': 1500, 'penalty': 'elasticnet', 'solver': 'saga'}
# nan (+/-nan) for {'C': 10, 'max_iter': 2000, 'penalty': 'l1', 'solver': 'newton-cg'}
# nan (+/-nan) for {'C': 10, 'max_iter': 2000, 'penalty': 'l1', 'solver': 'lbfgs'}
# 0.988 (+/-0.016) for {'C': 10, 'max_iter': 2000, 'penalty': 'l1', 'solver': 'liblinear'}
# nan (+/-nan) for {'C': 10, 'max_iter': 2000, 'penalty': 'l1', 'solver': 'sag'}
# 0.986 (+/-0.032) for {'C': 10, 'max_iter': 2000, 'penalty': 'l1', 'solver': 'saga'}
# 0.988 (+/-0.026) for {'C': 10, 'max_iter': 2000, 'penalty': 'l2', 'solver': 'newton-cg'}
# 0.988 (+/-0.026) for {'C': 10, 'max_iter': 2000, 'penalty': 'l2', 'solver': 'lbfgs'}
# 0.987 (+/-0.015) for {'C': 10, 'max_iter': 2000, 'penalty': 'l2', 'solver': 'liblinear'}
# 0.988 (+/-0.026) for {'C': 10, 'max_iter': 2000, 'penalty': 'l2', 'solver': 'sag'}
# 0.988 (+/-0.026) for {'C': 10, 'max_iter': 2000, 'penalty': 'l2', 'solver': 'saga'}
# nan (+/-nan) for {'C': 10, 'max_iter': 2000, 'penalty': 'elasticnet', 'solver': 'newton-cg'}
# nan (+/-nan) for {'C': 10, 'max_iter': 2000, 'penalty': 'elasticnet', 'solver': 'lbfgs'}
# nan (+/-nan) for {'C': 10, 'max_iter': 2000, 'penalty': 'elasticnet', 'solver': 'liblinear'}
# nan (+/-nan) for {'C': 10, 'max_iter': 2000, 'penalty': 'elasticnet', 'solver': 'sag'}
# nan (+/-nan) for {'C': 10, 'max_iter': 2000, 'penalty': 'elasticnet', 'solver': 'saga'}
# nan (+/-nan) for {'C': 100, 'max_iter': 250, 'penalty': 'l1', 'solver': 'newton-cg'}
# nan (+/-nan) for {'C': 100, 'max_iter': 250, 'penalty': 'l1', 'solver': 'lbfgs'}
# 0.988 (+/-0.018) for {'C': 100, 'max_iter': 250, 'penalty': 'l1', 'solver': 'liblinear'}
# nan (+/-nan) for {'C': 100, 'max_iter': 250, 'penalty': 'l1', 'solver': 'sag'}
# 0.987 (+/-0.024) for {'C': 100, 'max_iter': 250, 'penalty': 'l1', 'solver': 'saga'}
# 0.987 (+/-0.028) for {'C': 100, 'max_iter': 250, 'penalty': 'l2', 'solver': 'newton-cg'}
# 0.987 (+/-0.028) for {'C': 100, 'max_iter': 250, 'penalty': 'l2', 'solver': 'lbfgs'}
# 0.988 (+/-0.017) for {'C': 100, 'max_iter': 250, 'penalty': 'l2', 'solver': 'liblinear'}
# 0.988 (+/-0.024) for {'C': 100, 'max_iter': 250, 'penalty': 'l2', 'solver': 'sag'}
# 0.987 (+/-0.024) for {'C': 100, 'max_iter': 250, 'penalty': 'l2', 'solver': 'saga'}
# nan (+/-nan) for {'C': 100, 'max_iter': 250, 'penalty': 'elasticnet', 'solver': 'newton-cg'}
# nan (+/-nan) for {'C': 100, 'max_iter': 250, 'penalty': 'elasticnet', 'solver': 'lbfgs'}
# nan (+/-nan) for {'C': 100, 'max_iter': 250, 'penalty': 'elasticnet', 'solver': 'liblinear'}
# nan (+/-nan) for {'C': 100, 'max_iter': 250, 'penalty': 'elasticnet', 'solver': 'sag'}
# nan (+/-nan) for {'C': 100, 'max_iter': 250, 'penalty': 'elasticnet', 'solver': 'saga'}
# nan (+/-nan) for {'C': 100, 'max_iter': 500, 'penalty': 'l1', 'solver': 'newton-cg'}
# nan (+/-nan) for {'C': 100, 'max_iter': 500, 'penalty': 'l1', 'solver': 'lbfgs'}
# 0.988 (+/-0.018) for {'C': 100, 'max_iter': 500, 'penalty': 'l1', 'solver': 'liblinear'}
# nan (+/-nan) for {'C': 100, 'max_iter': 500, 'penalty': 'l1', 'solver': 'sag'}
# 0.987 (+/-0.025) for {'C': 100, 'max_iter': 500, 'penalty': 'l1', 'solver': 'saga'}
# 0.987 (+/-0.028) for {'C': 100, 'max_iter': 500, 'penalty': 'l2', 'solver': 'newton-cg'}
# 0.987 (+/-0.028) for {'C': 100, 'max_iter': 500, 'penalty': 'l2', 'solver': 'lbfgs'}
# 0.988 (+/-0.017) for {'C': 100, 'max_iter': 500, 'penalty': 'l2', 'solver': 'liblinear'}
# 0.987 (+/-0.026) for {'C': 100, 'max_iter': 500, 'penalty': 'l2', 'solver': 'sag'}
# 0.987 (+/-0.025) for {'C': 100, 'max_iter': 500, 'penalty': 'l2', 'solver': 'saga'}
# nan (+/-nan) for {'C': 100, 'max_iter': 500, 'penalty': 'elasticnet', 'solver': 'newton-cg'}
# nan (+/-nan) for {'C': 100, 'max_iter': 500, 'penalty': 'elasticnet', 'solver': 'lbfgs'}
# nan (+/-nan) for {'C': 100, 'max_iter': 500, 'penalty': 'elasticnet', 'solver': 'liblinear'}
# nan (+/-nan) for {'C': 100, 'max_iter': 500, 'penalty': 'elasticnet', 'solver': 'sag'}
# nan (+/-nan) for {'C': 100, 'max_iter': 500, 'penalty': 'elasticnet', 'solver': 'saga'}
# nan (+/-nan) for {'C': 100, 'max_iter': 1000, 'penalty': 'l1', 'solver': 'newton-cg'}
# nan (+/-nan) for {'C': 100, 'max_iter': 1000, 'penalty': 'l1', 'solver': 'lbfgs'}
# 0.988 (+/-0.018) for {'C': 100, 'max_iter': 1000, 'penalty': 'l1', 'solver': 'liblinear'}
# nan (+/-nan) for {'C': 100, 'max_iter': 1000, 'penalty': 'l1', 'solver': 'sag'}
# 0.987 (+/-0.027) for {'C': 100, 'max_iter': 1000, 'penalty': 'l1', 'solver': 'saga'}
# 0.987 (+/-0.028) for {'C': 100, 'max_iter': 1000, 'penalty': 'l2', 'solver': 'newton-cg'}
# 0.987 (+/-0.028) for {'C': 100, 'max_iter': 1000, 'penalty': 'l2', 'solver': 'lbfgs'}
# 0.988 (+/-0.017) for {'C': 100, 'max_iter': 1000, 'penalty': 'l2', 'solver': 'liblinear'}
# 0.987 (+/-0.026) for {'C': 100, 'max_iter': 1000, 'penalty': 'l2', 'solver': 'sag'}
# 0.987 (+/-0.026) for {'C': 100, 'max_iter': 1000, 'penalty': 'l2', 'solver': 'saga'}
# nan (+/-nan) for {'C': 100, 'max_iter': 1000, 'penalty': 'elasticnet', 'solver': 'newton-cg'}
# nan (+/-nan) for {'C': 100, 'max_iter': 1000, 'penalty': 'elasticnet', 'solver': 'lbfgs'}
# nan (+/-nan) for {'C': 100, 'max_iter': 1000, 'penalty': 'elasticnet', 'solver': 'liblinear'}
# nan (+/-nan) for {'C': 100, 'max_iter': 1000, 'penalty': 'elasticnet', 'solver': 'sag'}
# nan (+/-nan) for {'C': 100, 'max_iter': 1000, 'penalty': 'elasticnet', 'solver': 'saga'}
# nan (+/-nan) for {'C': 100, 'max_iter': 1500, 'penalty': 'l1', 'solver': 'newton-cg'}
# nan (+/-nan) for {'C': 100, 'max_iter': 1500, 'penalty': 'l1', 'solver': 'lbfgs'}
# 0.988 (+/-0.018) for {'C': 100, 'max_iter': 1500, 'penalty': 'l1', 'solver': 'liblinear'}
# nan (+/-nan) for {'C': 100, 'max_iter': 1500, 'penalty': 'l1', 'solver': 'sag'}
# 0.987 (+/-0.028) for {'C': 100, 'max_iter': 1500, 'penalty': 'l1', 'solver': 'saga'}
# 0.987 (+/-0.028) for {'C': 100, 'max_iter': 1500, 'penalty': 'l2', 'solver': 'newton-cg'}
# 0.987 (+/-0.028) for {'C': 100, 'max_iter': 1500, 'penalty': 'l2', 'solver': 'lbfgs'}
# 0.988 (+/-0.017) for {'C': 100, 'max_iter': 1500, 'penalty': 'l2', 'solver': 'liblinear'}
# 0.987 (+/-0.027) for {'C': 100, 'max_iter': 1500, 'penalty': 'l2', 'solver': 'sag'}
# 0.987 (+/-0.026) for {'C': 100, 'max_iter': 1500, 'penalty': 'l2', 'solver': 'saga'}
# nan (+/-nan) for {'C': 100, 'max_iter': 1500, 'penalty': 'elasticnet', 'solver': 'newton-cg'}
# nan (+/-nan) for {'C': 100, 'max_iter': 1500, 'penalty': 'elasticnet', 'solver': 'lbfgs'}
# nan (+/-nan) for {'C': 100, 'max_iter': 1500, 'penalty': 'elasticnet', 'solver': 'liblinear'}
# nan (+/-nan) for {'C': 100, 'max_iter': 1500, 'penalty': 'elasticnet', 'solver': 'sag'}
# nan (+/-nan) for {'C': 100, 'max_iter': 1500, 'penalty': 'elasticnet', 'solver': 'saga'}
# nan (+/-nan) for {'C': 100, 'max_iter': 2000, 'penalty': 'l1', 'solver': 'newton-cg'}
# nan (+/-nan) for {'C': 100, 'max_iter': 2000, 'penalty': 'l1', 'solver': 'lbfgs'}
# 0.988 (+/-0.018) for {'C': 100, 'max_iter': 2000, 'penalty': 'l1', 'solver': 'liblinear'}
# nan (+/-nan) for {'C': 100, 'max_iter': 2000, 'penalty': 'l1', 'solver': 'sag'}
# 0.986 (+/-0.029) for {'C': 100, 'max_iter': 2000, 'penalty': 'l1', 'solver': 'saga'}
# 0.987 (+/-0.028) for {'C': 100, 'max_iter': 2000, 'penalty': 'l2', 'solver': 'newton-cg'}
# 0.987 (+/-0.028) for {'C': 100, 'max_iter': 2000, 'penalty': 'l2', 'solver': 'lbfgs'}
# 0.988 (+/-0.017) for {'C': 100, 'max_iter': 2000, 'penalty': 'l2', 'solver': 'liblinear'}
# 0.987 (+/-0.027) for {'C': 100, 'max_iter': 2000, 'penalty': 'l2', 'solver': 'sag'}
# 0.988 (+/-0.026) for {'C': 100, 'max_iter': 2000, 'penalty': 'l2', 'solver': 'saga'}
# nan (+/-nan) for {'C': 100, 'max_iter': 2000, 'penalty': 'elasticnet', 'solver': 'newton-cg'}
# nan (+/-nan) for {'C': 100, 'max_iter': 2000, 'penalty': 'elasticnet', 'solver': 'lbfgs'}
# nan (+/-nan) for {'C': 100, 'max_iter': 2000, 'penalty': 'elasticnet', 'solver': 'liblinear'}
# nan (+/-nan) for {'C': 100, 'max_iter': 2000, 'penalty': 'elasticnet', 'solver': 'sag'}
# nan (+/-nan) for {'C': 100, 'max_iter': 2000, 'penalty': 'elasticnet', 'solver': 'saga'}
# nan (+/-nan) for {'C': 1000, 'max_iter': 250, 'penalty': 'l1', 'solver': 'newton-cg'}
# nan (+/-nan) for {'C': 1000, 'max_iter': 250, 'penalty': 'l1', 'solver': 'lbfgs'}
# 0.988 (+/-0.018) for {'C': 1000, 'max_iter': 250, 'penalty': 'l1', 'solver': 'liblinear'}
# nan (+/-nan) for {'C': 1000, 'max_iter': 250, 'penalty': 'l1', 'solver': 'sag'}
# 0.987 (+/-0.024) for {'C': 1000, 'max_iter': 250, 'penalty': 'l1', 'solver': 'saga'}
# 0.986 (+/-0.031) for {'C': 1000, 'max_iter': 250, 'penalty': 'l2', 'solver': 'newton-cg'}
# 0.986 (+/-0.031) for {'C': 1000, 'max_iter': 250, 'penalty': 'l2', 'solver': 'lbfgs'}
# 0.987 (+/-0.019) for {'C': 1000, 'max_iter': 250, 'penalty': 'l2', 'solver': 'liblinear'}
# 0.988 (+/-0.024) for {'C': 1000, 'max_iter': 250, 'penalty': 'l2', 'solver': 'sag'}
# 0.987 (+/-0.024) for {'C': 1000, 'max_iter': 250, 'penalty': 'l2', 'solver': 'saga'}
# nan (+/-nan) for {'C': 1000, 'max_iter': 250, 'penalty': 'elasticnet', 'solver': 'newton-cg'}
# nan (+/-nan) for {'C': 1000, 'max_iter': 250, 'penalty': 'elasticnet', 'solver': 'lbfgs'}
# nan (+/-nan) for {'C': 1000, 'max_iter': 250, 'penalty': 'elasticnet', 'solver': 'liblinear'}
# nan (+/-nan) for {'C': 1000, 'max_iter': 250, 'penalty': 'elasticnet', 'solver': 'sag'}
# nan (+/-nan) for {'C': 1000, 'max_iter': 250, 'penalty': 'elasticnet', 'solver': 'saga'}
# nan (+/-nan) for {'C': 1000, 'max_iter': 500, 'penalty': 'l1', 'solver': 'newton-cg'}
# nan (+/-nan) for {'C': 1000, 'max_iter': 500, 'penalty': 'l1', 'solver': 'lbfgs'}
# 0.988 (+/-0.018) for {'C': 1000, 'max_iter': 500, 'penalty': 'l1', 'solver': 'liblinear'}
# nan (+/-nan) for {'C': 1000, 'max_iter': 500, 'penalty': 'l1', 'solver': 'sag'}
# 0.987 (+/-0.025) for {'C': 1000, 'max_iter': 500, 'penalty': 'l1', 'solver': 'saga'}
# 0.986 (+/-0.031) for {'C': 1000, 'max_iter': 500, 'penalty': 'l2', 'solver': 'newton-cg'}
# 0.986 (+/-0.031) for {'C': 1000, 'max_iter': 500, 'penalty': 'l2', 'solver': 'lbfgs'}
# 0.987 (+/-0.019) for {'C': 1000, 'max_iter': 500, 'penalty': 'l2', 'solver': 'liblinear'}
# 0.987 (+/-0.026) for {'C': 1000, 'max_iter': 500, 'penalty': 'l2', 'solver': 'sag'}
# 0.987 (+/-0.025) for {'C': 1000, 'max_iter': 500, 'penalty': 'l2', 'solver': 'saga'}
# nan (+/-nan) for {'C': 1000, 'max_iter': 500, 'penalty': 'elasticnet', 'solver': 'newton-cg'}
# nan (+/-nan) for {'C': 1000, 'max_iter': 500, 'penalty': 'elasticnet', 'solver': 'lbfgs'}
# nan (+/-nan) for {'C': 1000, 'max_iter': 500, 'penalty': 'elasticnet', 'solver': 'liblinear'}
# nan (+/-nan) for {'C': 1000, 'max_iter': 500, 'penalty': 'elasticnet', 'solver': 'sag'}
# nan (+/-nan) for {'C': 1000, 'max_iter': 500, 'penalty': 'elasticnet', 'solver': 'saga'}
# nan (+/-nan) for {'C': 1000, 'max_iter': 1000, 'penalty': 'l1', 'solver': 'newton-cg'}
# nan (+/-nan) for {'C': 1000, 'max_iter': 1000, 'penalty': 'l1', 'solver': 'lbfgs'}
# 0.988 (+/-0.018) for {'C': 1000, 'max_iter': 1000, 'penalty': 'l1', 'solver': 'liblinear'}
# nan (+/-nan) for {'C': 1000, 'max_iter': 1000, 'penalty': 'l1', 'solver': 'sag'}
# 0.988 (+/-0.026) for {'C': 1000, 'max_iter': 1000, 'penalty': 'l1', 'solver': 'saga'}
# 0.986 (+/-0.031) for {'C': 1000, 'max_iter': 1000, 'penalty': 'l2', 'solver': 'newton-cg'}
# 0.986 (+/-0.031) for {'C': 1000, 'max_iter': 1000, 'penalty': 'l2', 'solver': 'lbfgs'}
# 0.987 (+/-0.019) for {'C': 1000, 'max_iter': 1000, 'penalty': 'l2', 'solver': 'liblinear'}
# 0.987 (+/-0.027) for {'C': 1000, 'max_iter': 1000, 'penalty': 'l2', 'solver': 'sag'}
# 0.988 (+/-0.025) for {'C': 1000, 'max_iter': 1000, 'penalty': 'l2', 'solver': 'saga'}
# nan (+/-nan) for {'C': 1000, 'max_iter': 1000, 'penalty': 'elasticnet', 'solver': 'newton-cg'}
# nan (+/-nan) for {'C': 1000, 'max_iter': 1000, 'penalty': 'elasticnet', 'solver': 'lbfgs'}
# nan (+/-nan) for {'C': 1000, 'max_iter': 1000, 'penalty': 'elasticnet', 'solver': 'liblinear'}
# nan (+/-nan) for {'C': 1000, 'max_iter': 1000, 'penalty': 'elasticnet', 'solver': 'sag'}
# nan (+/-nan) for {'C': 1000, 'max_iter': 1000, 'penalty': 'elasticnet', 'solver': 'saga'}
# nan (+/-nan) for {'C': 1000, 'max_iter': 1500, 'penalty': 'l1', 'solver': 'newton-cg'}
# nan (+/-nan) for {'C': 1000, 'max_iter': 1500, 'penalty': 'l1', 'solver': 'lbfgs'}
# 0.988 (+/-0.018) for {'C': 1000, 'max_iter': 1500, 'penalty': 'l1', 'solver': 'liblinear'}
# nan (+/-nan) for {'C': 1000, 'max_iter': 1500, 'penalty': 'l1', 'solver': 'sag'}
# 0.987 (+/-0.026) for {'C': 1000, 'max_iter': 1500, 'penalty': 'l1', 'solver': 'saga'}
# 0.986 (+/-0.031) for {'C': 1000, 'max_iter': 1500, 'penalty': 'l2', 'solver': 'newton-cg'}
# 0.986 (+/-0.031) for {'C': 1000, 'max_iter': 1500, 'penalty': 'l2', 'solver': 'lbfgs'}
# 0.987 (+/-0.019) for {'C': 1000, 'max_iter': 1500, 'penalty': 'l2', 'solver': 'liblinear'}
# 0.987 (+/-0.028) for {'C': 1000, 'max_iter': 1500, 'penalty': 'l2', 'solver': 'sag'}
# 0.987 (+/-0.026) for {'C': 1000, 'max_iter': 1500, 'penalty': 'l2', 'solver': 'saga'}
# nan (+/-nan) for {'C': 1000, 'max_iter': 1500, 'penalty': 'elasticnet', 'solver': 'newton-cg'}
# nan (+/-nan) for {'C': 1000, 'max_iter': 1500, 'penalty': 'elasticnet', 'solver': 'lbfgs'}
# nan (+/-nan) for {'C': 1000, 'max_iter': 1500, 'penalty': 'elasticnet', 'solver': 'liblinear'}
# nan (+/-nan) for {'C': 1000, 'max_iter': 1500, 'penalty': 'elasticnet', 'solver': 'sag'}
# nan (+/-nan) for {'C': 1000, 'max_iter': 1500, 'penalty': 'elasticnet', 'solver': 'saga'}
# nan (+/-nan) for {'C': 1000, 'max_iter': 2000, 'penalty': 'l1', 'solver': 'newton-cg'}
# nan (+/-nan) for {'C': 1000, 'max_iter': 2000, 'penalty': 'l1', 'solver': 'lbfgs'}
# 0.988 (+/-0.018) for {'C': 1000, 'max_iter': 2000, 'penalty': 'l1', 'solver': 'liblinear'}
# nan (+/-nan) for {'C': 1000, 'max_iter': 2000, 'penalty': 'l1', 'solver': 'sag'}
# 0.987 (+/-0.027) for {'C': 1000, 'max_iter': 2000, 'penalty': 'l1', 'solver': 'saga'}
# 0.986 (+/-0.031) for {'C': 1000, 'max_iter': 2000, 'penalty': 'l2', 'solver': 'newton-cg'}
# 0.986 (+/-0.031) for {'C': 1000, 'max_iter': 2000, 'penalty': 'l2', 'solver': 'lbfgs'}
# 0.987 (+/-0.019) for {'C': 1000, 'max_iter': 2000, 'penalty': 'l2', 'solver': 'liblinear'}
# 0.987 (+/-0.030) for {'C': 1000, 'max_iter': 2000, 'penalty': 'l2', 'solver': 'sag'}
# 0.987 (+/-0.027) for {'C': 1000, 'max_iter': 2000, 'penalty': 'l2', 'solver': 'saga'}
# nan (+/-nan) for {'C': 1000, 'max_iter': 2000, 'penalty': 'elasticnet', 'solver': 'newton-cg'}
# nan (+/-nan) for {'C': 1000, 'max_iter': 2000, 'penalty': 'elasticnet', 'solver': 'lbfgs'}
# nan (+/-nan) for {'C': 1000, 'max_iter': 2000, 'penalty': 'elasticnet', 'solver': 'liblinear'}
# nan (+/-nan) for {'C': 1000, 'max_iter': 2000, 'penalty': 'elasticnet', 'solver': 'sag'}
# nan (+/-nan) for {'C': 1000, 'max_iter': 2000, 'penalty': 'elasticnet', 'solver': 'saga'}

# %%
{'C': 10, 'max_iter': 250, 'penalty': 'l1', 'solver': 'liblinear'}

# %%
# Training the Logistic Regression classfication model on the Training set
from sklearn.linear_model import LogisticRegression
classifier_logreg = LogisticRegression(C= 10 , penalty='l1', solver= 'liblinear', max_iter= 250, random_state=0)
classifier_logreg.fit(X_train, y_train)
# Out:
# LogisticRegression(C=10, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=250,
#                    multi_class='auto', n_jobs=None, penalty='l1',
#                    random_state=0, solver='liblinear', tol=0.0001, verbose=0,
#                    warm_start=False)

# %%
# Predicting the Test set results
y_results_logreg = classifier_logreg.predict(X_test)

# %%
#classification report
from sklearn import metrics
print(metrics.classification_report(y_test, y_results_logreg, digits = 8))
# Out:
#               precision    recall  f1-score   support
#
#            1  0.97149123 1.00000000 0.98553949       886
#            2  1.00000000 1.00000000 1.00000000       883
#            3  0.94638950 0.98519362 0.96540179       878
#            4  0.99132590 0.89988751 0.94339623       889
#            5  0.98887653 0.99775533 0.99329609       891
#            6  0.82058546 0.99541810 0.89958592       873
#            7  0.99438202 0.80454545 0.88944724       880
#            8  0.99648300 0.98952270 0.99299065       859
#
#     accuracy                      0.95894303      7039
#    macro avg  0.96369170 0.95904034 0.95870718      7039
# weighted avg  0.96383792 0.95894303 0.95873673      7039

# %%
#Model Evalation For Logistic Regression Classification Model
from sklearn.metrics import confusion_matrix
    
#confusion matrix

cm_logreg = confusion_matrix(y_test, y_results_logreg)
array = cm_logreg 
df_cm = pd.DataFrame(array, index = [i for i in "12345678"],
                  columns = [i for i in "12345678"])
plt.figure(figsize = (10,8))
sn.heatmap(df_cm, annot=True)

# %%
#accuracy_score, f1_score, recall_score,precision_score metrics
from sklearn.metrics import accuracy_score, f1_score, recall_score,precision_score
#accuracy
accuracy_logreg = accuracy_score(y_test, y_results_logreg)
print("accuracy:{}".format(accuracy_logreg))
#F1 score    
f1_score_logreg = f1_score(y_test, y_results_logreg, average='micro')
print("f1_score:{}".format(f1_score_logreg))
#Recall score
recall_score_logreg = recall_score(y_test, y_results_logreg, average='micro')
print("recall_score:{}".format(recall_score_logreg))
#Precision score
precision_score_logreg = precision_score(y_test, y_results_logreg, average='micro')
print("precision_score:{}".format(precision_score_logreg))
# Out:
# accuracy:0.9589430316806364
# f1_score:0.9589430316806364
# recall_score:0.9589430316806364
# precision_score:0.9589430316806364

# %%
df_cm
# Out:
#      1    2    3    4    5    6    7    8
# 1  886    0    0    0    0    0    0    0
# 2    0  883    0    0    0    0    0    0
# 3    1    0  865    7    1    4    0    0
# 4   23    0   43  800    0   22    1    0
# 5    0    0    0    0  889    0    0    2
# 6    0    0    1    0    0  869    3    0
# 7    2    0    5    0    0  164  708    1
# 8    0    0    0    0    9    0    0  850

# %%
sum = 0
for i in range(0,8,1):
     sum += df_cm.iloc[i][i]
print("number of correctly classified samples in the test set: {}".format(sum))
# Out:
# number of correctly classified samples in the test set: 6750

# %%
import matplotlib.pyplot as plt
from itertools import cycle
from numpy import interp
from sklearn.metrics import roc_curve, auc
from sklearn.preprocessing import label_binarize
from sklearn.metrics import roc_auc_score

# Binarize the output
y_test = label_binarize(y_test, classes=[ 1, 2, 3, 4, 5, 6, 7, 8])
n_classes = y_test.shape[1]

# Learn to predict each class against the other
y_score = y_results_logreg
y_score = label_binarize(y_score, classes=[ 1, 2, 3, 4, 5, 6, 7, 8])


# Compute ROC curve and ROC area for each class
fpr = dict()
tpr = dict()
roc_auc = dict()
for i in range(n_classes):
    fpr[i], tpr[i], _ = roc_curve(y_test[:, i], y_score[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])

# Compute micro-average ROC curve and ROC area
fpr["micro"], tpr["micro"], _ = roc_curve(y_test.ravel(), y_score.ravel())
roc_auc["micro"] = auc(fpr["micro"], tpr["micro"])

# %%
# First aggregate all false positive rates
all_fpr = np.unique(np.concatenate([fpr[i] for i in range(n_classes)]))

# Then interpolate all ROC curves at this points
mean_tpr = np.zeros_like(all_fpr)
for i in range(n_classes):
    mean_tpr += interp(all_fpr, fpr[i], tpr[i])

# Finally average it and compute AUC
mean_tpr /= n_classes

fpr["macro"] = all_fpr
tpr["macro"] = mean_tpr
roc_auc["macro"] = auc(fpr["macro"], tpr["macro"])

# %%
# Plot all ROC curves
plt.figure(figsize = (16,16))
plt.plot(fpr["micro"], tpr["micro"],
         label='micro-average ROC curve (area = {0:0.4f})'
               ''.format(roc_auc["micro"]),
         color='deeppink', linestyle=':', linewidth=4)

plt.plot(fpr["macro"], tpr["macro"],
         label='macro-average ROC curve (area = {0:0.4f})'
               ''.format(roc_auc["macro"]),
         color='navy', linestyle=':', linewidth=4)

colors = cycle(['green', 'orange','pink','red','yellow','brown','violet','blue'])
for i, color in zip(range(n_classes), colors):
    plt.plot(fpr[i], tpr[i], color=color, lw=2,
             label='ROC curve of class {0} (area = {1:0.4f})'
             ''.format(i+1 , roc_auc[i]))

plt.plot([0, 1], [0, 1], 'k--', lw = 2)
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver operating characteristic')
plt.legend(loc="lower right")
plt.show()

# %%
from sklearn.metrics import precision_recall_curve
from sklearn.metrics import average_precision_score

# For each class
precision = dict()
recall = dict()
average_precision = dict()
for i in range(n_classes):
    precision[i], recall[i], _ = precision_recall_curve(y_test[:, i],
                                                        y_score[:, i])
    average_precision[i] = average_precision_score(y_test[:, i], y_score[:, i])

# A "micro-average": quantifying score on all classes jointly
precision["micro"], recall["micro"], _ = precision_recall_curve(y_test.ravel(),
                                                                y_score.ravel())
average_precision["micro"] = average_precision_score(y_test, y_score,
                                                     average="micro")
print('Average precision score, micro-averaged over all classes: {0:0.4f}'
      .format(average_precision["micro"]))
# Out:
# Average precision score, micro-averaged over all classes: 0.9247

# %%
# setup plot details
colors = cycle(['navy', 'turquoise', 'darkorange', 'cornflowerblue', 'teal'])

plt.figure(figsize=(16,16))
f_scores = np.linspace(0.2, 0.8, num=4)
lines = []
labels = []
for i, color in zip(range(n_classes), colors):
    l, = plt.plot(recall[i], precision[i], color=color, lw=2)
    lines.append(l)
    labels.append('Precision-recall for class {0} (area = {1:0.4f})'
                  ''.format(i+1, average_precision[i]))

fig = plt.gcf()
fig.subplots_adjust(bottom=0.25)
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.title('Precision-Recall curve')
plt.legend(lines, labels, loc=(0, -.38), prop=dict(size=14))


plt.show()
